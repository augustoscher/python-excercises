# %% [markdown]
# <a href="https://colab.research.google.com/github/augustoscher/python-excercises/blob/master/augusto_tests.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
stopwords = nltk.corpus.stopwords.words('portuguese')

# %%
stopwords
# Out:
# ['a',
#  'à',
#  'ao',
#  'aos',
#  'aquela',
#  'aquelas',
#  'aquele',
#  'aqueles',
#  'aquilo',
#  'as',
#  'às',
#  'até',
#  'com',
#  'como',
#  'da',
#  'das',
#  'de',
#  'dela',
#  'delas',
#  'dele',
#  'deles',
#  'depois',
#  'do',
#  'dos',
#  'e',
#  'é',
#  'ela',
#  'elas',
#  'ele',
#  'eles',
#  'em',
#  'entre',
#  'era',
#  'eram',
#  'éramos',
#  'essa',
#  'essas',
#  'esse',
#  'esses',
#  'esta',
#  'está',
#  'estamos',
#  'estão',
#  'estar',
#  'estas',
#  'estava',
#  'estavam',
#  'estávamos',
#  'este',
#  'esteja',
#  'estejam',
#  'estejamos',
#  'estes',
#  'esteve',
#  'estive',
#  'estivemos',
#  'estiver',
#  'estivera',
#  'estiveram',
#  'estivéramos',
#  'estiverem',
#  'estivermos',
#  'estivesse',
#  'estivessem',
#  'estivéssemos',
#  'estou',
#  'eu',
#  'foi',
#  'fomos',
#  'for',
#  'fora',
#  'foram',
#  'fôramos',
#  'forem',
#  'formos',
#  'fosse',
#  'fossem',
#  'fôssemos',
#  'fui',
#  'há',
#  'haja',
#  'hajam',
#  'hajamos',
#  'hão',
#  'havemos',
#  'haver',
#  'hei',
#  'houve',
#  'houvemos',
#  'houver',
#  'houvera',
#  'houverá',
#  'houveram',
#  'houvéramos',
#  'houverão',
#  'houverei',
#  'houverem',
#  'houveremos',
#  'houveria',
#  'houveriam',
#  'houveríamos',
#  'houvermos',
#  'houvesse',
#  'houvessem',
#  'houvéssemos',
#  'isso',
#  'isto',
#  'já',
#  'lhe',
#  'lhes',
#  'mais',
#  'mas',
#  'me',
#  'mesmo',
#  'meu',
#  'meus',
#  'minha',
#  'minhas',
#  'muito',
#  'na',
#  'não',
#  'nas',
#  'nem',
#  'no',
#  'nos',
#  'nós',
#  'nossa',
#  'nossas',
#  'nosso',
#  'nossos',
#  'num',
#  'numa',
#  'o',
#  'os',
#  'ou',
#  'para',
#  'pela',
#  'pelas',
#  'pelo',
#  'pelos',
#  'por',
#  'qual',
#  'quando',
#  'que',
#  'quem',
#  'são',
#  'se',
#  'seja',
#  'sejam',
#  'sejamos',
#  'sem',
#  'ser',
#  'será',
#  'serão',
#  'serei',
#  'seremos',
#  'seria',
#  'seriam',
#  'seríamos',
#  'seu',
#  'seus',
#  'só',
#  'somos',
#  'sou',
#  'sua',
#  'suas',
#  'também',
#  'te',
#  'tem',
#  'tém',
#  'temos',
#  'tenha',
#  'tenham',
#  'tenhamos',
#  'tenho',
#  'terá',
#  'terão',
#  'terei',
#  'teremos',
#  'teria',
#  'teriam',
#  'teríamos',
#  'teu',
#  'teus',
#  'teve',
#  'tinha',
#  'tinham',
#  'tínhamos',
#  'tive',
#  'tivemos',
#  'tiver',
#  'tivera',
#  'tiveram',
#  'tivéramos',
#  'tiverem',
#  'tivermos',
#  'tivesse',
#  'tivessem',
#  'tivéssemos',
#  'tu',
#  'tua',
#  'tuas',
#  'um',
#  'uma',
#  'você',
#  'vocês',
#  'vos']

# %%
len(stopwords)
# Out:
# 207

# %%
pip install enelvo
# Out:
# Collecting enelvo
#   Downloading enelvo-0.15-py3-none-any.whl (27.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.5/27.5 MB 12.8 MB/s eta 0:00:00
# Requirement already satisfied: editdistance>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from enelvo) (0.6.2)
# Collecting emoji==2.2.0 (from enelvo)
#   Downloading emoji-2.2.0.tar.gz (240 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 240.9/240.9 kB 35.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: gensim>=4.1.2 in /usr/local/lib/python3.10/dist-packages (from enelvo) (4.3.2)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.10/dist-packages (from enelvo) (1.23.5)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.10/dist-packages (from enelvo) (0.9.0)
# Requirement already satisfied: scipy>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from gensim>=4.1.2->enelvo) (1.11.3)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.10/dist-packages (from gensim>=4.1.2->enelvo) (6.4.0)
# Building wheels for collected packages: emoji
#   Building wheel for emoji (setup.py) ... done
#   Created wheel for emoji: filename=emoji-2.2.0-py3-none-any.whl size=234912 sha256=974180cb39e4502a748c5955cad88459b8669f21ce297281baa44e186bf9c878
#   Stored in directory: /root/.cache/pip/wheels/02/3d/88/51a592b9ad17e7899126563698b4e3961983ebe85747228ba6
# Successfully built emoji
# Installing collected packages: emoji, enelvo
# Successfully installed emoji-2.2.0 enelvo-0.15

# %%
from enelvo.normaliser import Normaliser

# %%
normalizer = Normaliser(tokenizer='readable', capitalize_inis=True,
                          capitalize_pns=True, capitalize_acs=True,
                          sanitize=True)

# %%
normalizer.normalise("danos morais por atraso de voo com atraso de 4 horas que não foi avisado")
# Out:
# 'Danos morais por atraso de voo com atraso de 4 horas que não foi avisado'

# %%
 pip install spacy
# Out:
# Requirement already satisfied: spacy in /usr/local/lib/python3.10/dist-packages (3.6.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /usr/local/lib/python3.10/dist-packages (from spacy) (8.1.12)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.0.10)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (0.9.0)
# Requirement already satisfied: pathy>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (0.10.3)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (4.66.1)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.23.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.10.13)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.1.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (23.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.3.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2023.7.22)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy) (0.1.3)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.10.0,>=0.3.0->spacy) (8.1.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy) (2.1.3)

# %%
# !python3 -m spacy download pt_core_news_sm
# Out:
# 2023-11-03 15:15:12.359038: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-03 15:15:12.359099: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-03 15:15:12.359129: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-03 15:15:12.364558: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-11-03 15:15:13.365053: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Collecting pt-core-news-sm==3.6.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/pt_core_news_sm-3.6.0/pt_core_news_sm-3.6.0-py3-none-any.whl (13.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.0/13.0 MB 41.9 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.7.0,>=3.6.0 in /usr/local/lib/python3.10/dist-packages (from pt-core-news-sm==3.6.0) (3.6.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->pt-core-news-sm==3.6.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->pt-core-news-sm==3.6.0) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->pt-core-news-sm==3.6.0) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->pt-core-news-sm==3.6.0) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->pt-core-news-sm==3.6.0) (3.0.9)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->pt-core-news-sm==3.6.0) (8.1.12)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->pt-core-news-sm==3.6.0) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->pt-core-news-sm==3.6.0) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->pt-core-news-sm==3.6.0) (2.0.10)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->pt-core-news-sm==3.6.0) (0.9.0)
# Requirement already satisfied: pathy>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->pt-core-news-sm==3.6.0) (0.10.3)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->pt-core-news-sm==3.6.0) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->pt-core-news-sm==3.6.0) (4.66.1)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->pt-core-news-sm==3.6.0) (1.23.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->pt-core-news-sm==3.6.0) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->pt-core-news-sm==3.6.0) (1.10.13)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->pt-core-news-sm==3.6.0) (3.1.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->pt-core-news-sm==3.6.0) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->pt-core-news-sm==3.6.0) (23.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->pt-core-news-sm==3.6.0) (3.3.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.7.0,>=3.6.0->pt-core-news-sm==3.6.0) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->pt-core-news-sm==3.6.0) (3.3.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->pt-core-news-sm==3.6.0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->pt-core-news-sm==3.6.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->pt-core-news-sm==3.6.0) (2023.7.22)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy<3.7.0,>=3.6.0->pt-core-news-sm==3.6.0) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy<3.7.0,>=3.6.0->pt-core-news-sm==3.6.0) (0.1.3)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.10.0,>=0.3.0->spacy<3.7.0,>=3.6.0->pt-core-news-sm==3.6.0) (8.1.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy<3.7.0,>=3.6.0->pt-core-news-sm==3.6.0) (2.1.3)
# Installing collected packages: pt-core-news-sm
# Successfully installed pt-core-news-sm-3.6.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('pt_core_news_sm')

# %%
import spacy

# %%
nlp = spacy.load("pt_core_news_sm")

# %%
doc = nlp("danos morais por atraso de mais de 4h em voo doméstico")

# %%
for token in doc:
    print(token.text)
# Out:
# danos
# morais
# por
# atraso
# de
# mais
# de
# 4h
# em
# voo
# doméstico

# %%
for token in doc:
    print(token.text, token.lemma_)
# Out:
# danos dano
# morais moral
# por por
# atraso atraso
# de de
# mais mais
# de de
# 4h 4h
# em em
# voo voo
# doméstico doméstico

# %%
for ent in doc.ents:
    print(ent.text, ent.label_)

# %%
doc.ents
# Out:
# ()

# %%
doc2 = nlp("O juiz federal Leandro Paulo Cypriani, da 1ª Vara Federal de Blumenau, determinou a demolição do Grand Trianon, um dos maiores edifícios da cidade de Blumenau, com 35 andares, localizado na Avenida Brasil, no bairro Ponta Aguda.")

# %%
doc2.ents
# Out:
# (Leandro Paulo Cypriani,
#  Vara Federal,
#  Blumenau,
#  Grand Trianon,
#  Blumenau,
#  Avenida Brasil,
#  Ponta Aguda)

# %%
for ent in doc2.ents:
    print(ent.text, ent.label_)
# Out:
# Leandro Paulo Cypriani PER
# Vara Federal LOC
# Blumenau LOC
# Grand Trianon LOC
# Blumenau LOC
# Avenida Brasil LOC
# Ponta Aguda LOC

# %%
import numpy as np
import pandas as pd

# %%
print('1. Criando Datafram com base em dicionario')
data = {'Empresa': ['GOOG', 'GOOG', 'MSFT', 'MSFT', 'FB', 'FB'],
'Nome':['Sam', 'Charlie', 'Any', 'Vanessa', 'Carl', 'Sarah'],
'Venda':[200, 120, 340, 124, 243, 350]}
# Out:
# 1. Criando Datafram com base em dicionario

# %%
print(data)
# Out:
# {'Empresa': ['GOOG', 'GOOG', 'MSFT', 'MSFT', 'FB', 'FB'], 'Nome': ['Sam', 'Charlie', 'Any', 'Vanessa', 'Carl', 'Sarah'], 'Venda': [200, 120, 340, 124, 243, 350]}

# %%
df = pd.DataFrame(data)
print(df)
# Out:
#   Empresa     Nome  Venda
# 0    GOOG      Sam    200
# 1    GOOG  Charlie    120
# 2    MSFT      Any    340
# 3    MSFT  Vanessa    124
# 4      FB     Carl    243
# 5      FB    Sarah    350

# %%
print('2. Agrupando dados de dataframe com groupBy - Empresa')
# Out:
# 2. Agrupando dados de dataframe com groupBy - Empresa

# %%
groupEmpresa = df.groupby('Empresa')

# %%
groupEmpresa.describe()
# Out:
#         Venda
#         count   mean         std    min     25%    50%     75%    max
# Empresa
# FB        2.0  296.5   75.660426  243.0  269.75  296.5  323.25  350.0
# GOOG      2.0  160.0   56.568542  120.0  140.00  160.0  180.00  200.0
# MSFT      2.0  232.0  152.735065  124.0  178.00  232.0  286.00  340.0

# %%
import pandas as pd

# %%
df = pd.read_parquet('part-0.parquet')

# %%
print(df)
# Out:
#               id                                          embedding  \
# 0       14755062  [0.0024910897482278457, 0.007275670981219333, ...
# 1        3441988  [0.00011509641879072941, 0.017347231557194025,...
# 2        4866779  [-0.027918996153871903, -0.005624693325430501,...
# 3        6253730  [-0.0098970524645175, 0.009636432082501473, 0....
# 4        3400103  [-0.02852786660601655, -7.575850408581962e-05,...
# ...          ...                                                ...
# 2133   401180960  [-0.008031040341581218, -0.0020811944039333323...
# 2134  1123711509  [-0.00787744714121248, -0.003229013121987619, ...
# 2135   129329409  [-0.02300492885466366, 0.021823123335426096, 0...
# 2136  1122383911  [-0.017359895975476262, -0.0025296814389098145...
# 2137   395304541  [-0.008383278724217786, 0.01646785060098819, 0...
#
#                                                    text
# 0     Recurso especial. Falta de prequestionamento ....
# 1     H.C. - INCIDENTE DE SANIDADE MENTAL - EXCESSO ...
# 2     Caderneta de poupança - Ação de cobrança - Cru...
# 3     EMBARGOS DE DECLARAÇÃO. PRESSUPOSTOS. INOCORRÊ...
# 4     "EXECUÇÃO. AO CREDOR É FACULTADO O DIREITO DE ...
# ...                                                 ...
# 2133  AÇÃO SUMÁRIA DE REPARAÇÃO CIVIL. PRESCRIÇÃO. R...
# 2134  PENAL - ESTELIONATO - FURTO DE TALÃO DE CHEQUE...
# 2135  AGRAVO DE PETIÇÃO PENHORA DINHEIRO INSTITUIÇÃO...
# 2136  Agravos de Instrumento - Ações de Cobrança de ...
# 2137  Apelação cível. Partilha de bens. Imóvel adqui...
#
# [2138 rows x 3 columns]

# %%
import pandas as pd

class PreProcessedEmbeddingLoader:
    def __init__(self, file_path: str):
        self.file_path = file_path

    def load(self):
        return pd.read_parquet(path=self.file_path, engine='pyarrow', columns=['id', 'embedding'])

# %%
class PreProcessedEmbeddingWritter:
    def __init__(self):
        print('')

    def write(self, doc_id: str, embbedding: list[float], model_name: str):
        print(doc_id)

# %%
class EmbeddingsFileProcessor:
    def __init__(self, file_path: str):
        self.loader = PreProcessedEmbeddingLoader(file_path=file_path)
        self.writer = PreProcessedEmbeddingWritter()

    def process(self):
        embeddings_df = self.loader.load()
        for _, row in embeddings_df.iterrows():
          doc_id = row["id"]
          embbedding = row["embedding"]
          self.writer.write(doc_id=doc_id, embbedding=embbedding, model_name='ada-002')

# %%
file_processor = EmbeddingsFileProcessor('part-0.parquet')
file_processor.process()
# Out:
# 14755062
# 3441988
# 4866779
# 6253730
# 3400103
# 3416444
# 6188419
# 5544834
# 115703
# 212200
# 208500
# 70061
# 6419175
# 651995
# 662839
# 5676705
# 957054
# 618439
# 742670
# 3766927
# 1340874
# 1030980
# 5109456
# 559563
# 216372
# 1121259152
# 736711
# 1723407
# 393760
# 1123717676
# 7900046
# 49807
# 522088
# 4677646
# 5002775
# 299660
# 692245
# 707106
# 14322998
# 4400482
# 456463
# 9274
# 7708058
# 6265033
# 349542
# 3873967
# 594150
# 319549
# 143542
# 647013
# 285709
# 338086
# 6582565
# 144008
# 3639117
# 595697
# 3339457
# 3463894
# 330328
# 696851
# 4119369
# 1124031147
# 4389678
# 955319
# 30086
# 2379014
# 707831
# 716659
# 3983693
# 123929
# 5224027
# 1123839830
# 5468086
# 4410042
# 273915
# 6235521
# 691879
# 2897993
# 3654147
# 55209
# 6344873
# 6084080
# 23197847
# 6063144
# 1121238628
# 711205
# 2623679
# 30418
# 4346682
# 107504
# 427630
# 1148901
# 2781030
# 221110
# 3028850
# 831001
# 906477
# 4802047
# 1123607134
# 949877
# 77176
# 7454723
# 562976
# 402864730
# 787245
# 395676339
# 8000822
# 162237
# 4067766
# 5209726
# 1122382524
# 4444862
# 6064609
# 2056054
# 6105885
# 128833329
# 6235528
# 4390260
# 662879
# 155717
# 130194553
# 2054504
# 10038
# 6295681
# 1123804142
# 5698282
# 57994
# 6257441
# 16967503
# 900728
# 5397189
# 231442
# 587235
# 2062998
# 876778
# 406755352
# 5316014
# 711919
# 274122
# 14591082
# 688317
# 6348370
# 6129528
# 255762
# 925269
# 8101
# 129435
# 603559
# 79179
# 16866238
# 4244015
# 23313328
# 16996617
# 4907848
# 37639
# 1122838404
# 393669022
# 241673
# 8724234
# 14979412
# 787058
# 29408
# 1121829436
# 5026581
# 602155
# 226307
# 6390009
# 203865
# 4571534
# 6243789
# 2044315
# 47845
# 29811
# 1655195
# 130499905
# 129332094
# 1123723701
# 204316
# 1371171
# 1879770
# 6268179
# 2192146
# 6264263
# 378716
# 202530
# 6335300
# 5216089
# 3082750
# 265977
# 5243771
# 16731802
# 399888779
# 14590608
# 1123758769
# 6172166
# 4373509
# 5548084
# 5366
# 4465908
# 6201128
# 752056
# 5073932
# 2134202
# 879616
# 5375203
# 5665483
# 1604791
# 6306131
# 6181334
# 2350560
# 1264855
# 1121035094
# 1123875989
# 4418080
# 14709925
# 137932456
# 1123960373
# 3702761
# 1121192537
# 294776828
# 1032285
# 6718480
# 1121322671
# 394034948
# 15455559
# 6391656
# 1123747459
# 514113
# 6183043
# 16994057
# 14724818
# 1123790320
# 1121204466
# 1122824077
# 395828988
# 14504307
# 1122417681
# 1123760158
# 1122823560
# 23275738
# 1122302828
# 1121032986
# 401180960
# 1123711509
# 129329409
# 1122383911
# 395304541

# %%
outside = ['G1', 'G1', 'G1', 'G2', 'G2', 'G2']
inside = [1, 2, 3, 1, 2, 3]

# %%
hier_index = list(zip(outside, inside))
print(hier_index)
# Out:
# [('G1', 1), ('G1', 2), ('G1', 3), ('G2', 1), ('G2', 2), ('G2', 3)]

# %%
from typing import Optional, TextIO

def open_progress(progress_file_path: str) -> (TextIO, set[str]):
    progress_file = open(progress_file_path, "a+")
    try:
        progress_file.seek(0)
        done_files = set(
            filepath.strip() for filepath in progress_file if filepath.strip()
        )
        return progress_file, done_files
    except:
        progress_file.close()
        raise

# %%
progress_file, done_files = open_progress("progress-file")

# %%
print(progress_file)
# Out:
# <_io.TextIOWrapper name='progress-file' mode='a+' encoding='UTF-8'>

# %% [markdown]
# GCS_URI_RE = re.compile("^gs://([\w\-_]+)/([.\-_a-zA-Z0-9 /]+)$")
#
#
# def _list_on_gs(path: str, suffix: str = "") -> List[str]:
#     regex_matches = GCS_URI_RE.search(path)
#     bucket_name, prefix = regex_matches.group(1), regex_matches.group(2)
#
#     storage_client = storage.Client()
#     blobs = storage_client.list_blobs(bucket_name, prefix=prefix, delimiter="/")
#
#     files = [os.path.join("gs://", bucket_name, blob.name) for blob in blobs]
#     if suffix:
#         files = fnmatch.filter(files, suffix)
#     return files
#
#
# def _list_on_system(path: str, suffix: str = "") -> List[str]:
#     return glob.glob(os.path.join(path, suffix))
#
#
# def list_paths(path: str, suffix: str = "") -> List[str]:
#     if path.startswith("gs://"):
#         return _list_on_gs(path, suffix)
#
#     return _list_on_system(path, suffix)

# %%
import pandas as pd


def get_dataframe_from_parquet_file(file_path: str, columns: list[str]):
    return pd.read_parquet(path=file_path, engine="pyarrow", columns=columns)

# %%
class EmbeddingWriter:
    def __init__(self):
        print("init writter")
        # self.juris_embeddingdb = JurisEmbeddingDB(
        #     config=SCYLLA_CONFIG, host=CASSANDRA_HOST, keyspace="legalresearch"
        # )

    def write(self, doc_id: str, embbedding: list[float], model_name: str):
        # update_at = datetime.now().date()
        print(f"doc_id {doc_id}, embedding size: {len(embbedding)} ")
        # item = juris_embeddingdb.get_item(id=doc_id, model_name=model_name)
        # if item is None:
        #     item = JurisEmbeddingDBSchema(
        #         id=doc_id,
        #         embedding=embbedding,
        #         model_name=model_name,
        #         update_at=update_at,
        #     )
        #     juris_embeddingdb.insert_item(item=item)
        # else:
        #     item.embedding = embbedding
        #     item.update_at = update_at
        #     juris_embeddingdb.update_item(item=item)

# %%
class EmbeddingsFileProcessor:
    def __init__(self):
        self.writer = EmbeddingWriter()

    def process(self, file_path: str):
        embeddings_df = get_dataframe_from_parquet_file(
            file_path=file_path, columns=["id", "embedding"]
        )
        embeddings_df = embeddings_df.reset_index()
        for _, row in embeddings_df.iterrows():
            doc_id = row["id"]
            embbedding = row["embedding"]
            self.writer.write(
                doc_id=doc_id, embbedding=embbedding, model_name="ada-002"
            )
        del embeddings_df

# %%
embedding_processor = EmbeddingsFileProcessor()
# Out:
# init writter

# %%
embedding_processor.process(file_path='part-0.parquet')
# Out:
# doc_id 14755062, embedding size: 1536
# doc_id 3441988, embedding size: 1536
# doc_id 4866779, embedding size: 1536
# doc_id 6253730, embedding size: 1536
# doc_id 3400103, embedding size: 1536
# doc_id 3416444, embedding size: 1536
# doc_id 6188419, embedding size: 1536
# doc_id 5544834, embedding size: 1536
# doc_id 115703, embedding size: 1536
# doc_id 212200, embedding size: 1536
# doc_id 208500, embedding size: 1536
# doc_id 70061, embedding size: 1536
# doc_id 6419175, embedding size: 1536
# doc_id 651995, embedding size: 1536
# doc_id 662839, embedding size: 1536
# doc_id 5676705, embedding size: 1536
# doc_id 957054, embedding size: 1536
# doc_id 618439, embedding size: 1536
# doc_id 742670, embedding size: 1536
# doc_id 3766927, embedding size: 1536
# doc_id 1340874, embedding size: 1536
# doc_id 1030980, embedding size: 1536
# doc_id 5109456, embedding size: 1536
# doc_id 559563, embedding size: 1536
# doc_id 216372, embedding size: 1536
# doc_id 1121259152, embedding size: 1536
# doc_id 736711, embedding size: 1536
# doc_id 1723407, embedding size: 1536
# doc_id 393760, embedding size: 1536
# doc_id 1123717676, embedding size: 1536
# doc_id 7900046, embedding size: 1536
# doc_id 49807, embedding size: 1536
# doc_id 522088, embedding size: 1536
# doc_id 4677646, embedding size: 1536
# doc_id 5002775, embedding size: 1536
# doc_id 299660, embedding size: 1536
# doc_id 692245, embedding size: 1536
# doc_id 707106, embedding size: 1536
# doc_id 14322998, embedding size: 1536
# doc_id 4400482, embedding size: 1536
# doc_id 456463, embedding size: 1536
# doc_id 9274, embedding size: 1536
# doc_id 7708058, embedding size: 1536
# doc_id 6265033, embedding size: 1536
# doc_id 349542, embedding size: 1536
# doc_id 3873967, embedding size: 1536
# doc_id 594150, embedding size: 1536
# doc_id 319549, embedding size: 1536
# doc_id 143542, embedding size: 1536
# doc_id 647013, embedding size: 1536
# doc_id 285709, embedding size: 1536
# doc_id 338086, embedding size: 1536
# doc_id 6582565, embedding size: 1536
# doc_id 144008, embedding size: 1536
# doc_id 3639117, embedding size: 1536
# doc_id 595697, embedding size: 1536
# doc_id 3339457, embedding size: 1536
# doc_id 3463894, embedding size: 1536
# doc_id 330328, embedding size: 1536
# doc_id 696851, embedding size: 1536
# doc_id 4119369, embedding size: 1536
# doc_id 1124031147, embedding size: 1536
# doc_id 4389678, embedding size: 1536
# doc_id 955319, embedding size: 1536
# doc_id 30086, embedding size: 1536
# doc_id 2379014, embedding size: 1536
# doc_id 707831, embedding size: 1536
# doc_id 716659, embedding size: 1536
# doc_id 3983693, embedding size: 1536
# doc_id 123929, embedding size: 1536
# doc_id 5224027, embedding size: 1536
# doc_id 1123839830, embedding size: 1536
# doc_id 5468086, embedding size: 1536
# doc_id 4410042, embedding size: 1536
# doc_id 273915, embedding size: 1536
# doc_id 5896474, embedding size: 1536
# doc_id 1123592269, embedding size: 1536
# doc_id 114104, embedding size: 1536
# doc_id 6124862, embedding size: 1536
# doc_id 540432, embedding size: 1536
# doc_id 1060908, embedding size: 1536
# doc_id 6964891, embedding size: 1536
# doc_id 6136565, embedding size: 1536
# doc_id 749941, embedding size: 1536
# doc_id 726334, embedding size: 1536
# doc_id 130512598, embedding size: 1536
# doc_id 58840, embedding size: 1536
# doc_id 798440, embedding size: 1536
# doc_id 2425802, embedding size: 1536
# doc_id 4107805, embedding size: 1536
# doc_id 8118788, embedding size: 1536
# doc_id 5383679, embedding size: 1536
# doc_id 14720203, embedding size: 1536
# doc_id 771282, embedding size: 1536
# doc_id 2776277, embedding size: 1536
# doc_id 16542554, embedding size: 1536
# doc_id 1481575, embedding size: 1536
# doc_id 4244184, embedding size: 1536
# doc_id 4307454, embedding size: 1536
# doc_id 1121080724, embedding size: 1536
# doc_id 6275498, embedding size: 1536
# doc_id 4116585, embedding size: 1536
# doc_id 2762097, embedding size: 1536
# doc_id 2043196, embedding size: 1536
# doc_id 1367006, embedding size: 1536
# doc_id 7263353, embedding size: 1536
# doc_id 5538153, embedding size: 1536
# doc_id 623176, embedding size: 1536
# doc_id 1013747, embedding size: 1536
# doc_id 775112, embedding size: 1536
# doc_id 1121404518, embedding size: 1536
# doc_id 2458731, embedding size: 1536
# doc_id 6998939, embedding size: 1536
# doc_id 5666243, embedding size: 1536
# doc_id 123009, embedding size: 1536
# doc_id 592682, embedding size: 1536
# doc_id 1038874, embedding size: 1536
# doc_id 733254, embedding size: 1536
# doc_id 157684, embedding size: 1536
# doc_id 3983925, embedding size: 1536
# doc_id 531287, embedding size: 1536
# doc_id 2046437, embedding size: 1536
# doc_id 400442740, embedding size: 1536
# doc_id 2111561, embedding size: 1536
# doc_id 671874, embedding size: 1536
# doc_id 1997157, embedding size: 1536
# doc_id 4002990, embedding size: 1536
# doc_id 737414, embedding size: 1536
# doc_id 837070, embedding size: 1536
# doc_id 5454983, embedding size: 1536
# doc_id 452976, embedding size: 1536
# doc_id 2849759, embedding size: 1536
# doc_id 113025, embedding size: 1536
# doc_id 2911038, embedding size: 1536
# doc_id 6312249, embedding size: 1536
# doc_id 1123800892, embedding size: 1536
# doc_id 1447097, embedding size: 1536
# doc_id 4362402, embedding size: 1536
# doc_id 662247, embedding size: 1536
# doc_id 5637883, embedding size: 1536
# doc_id 14464160, embedding size: 1536
# doc_id 2962713, embedding size: 1536
# doc_id 577947, embedding size: 1536
# doc_id 14608955, embedding size: 1536
# doc_id 7645370, embedding size: 1536
# doc_id 15870883, embedding size: 1536
# doc_id 723549, embedding size: 1536
# doc_id 17656206, embedding size: 1536
# doc_id 15806136, embedding size: 1536
# doc_id 5381735, embedding size: 1536
# doc_id 2298399, embedding size: 1536
# doc_id 633303, embedding size: 1536
# doc_id 5048754, embedding size: 1536
# doc_id 1122356115, embedding size: 1536
# doc_id 809666, embedding size: 1536
# doc_id 342683010, embedding size: 1536
# doc_id 7070, embedding size: 1536
# doc_id 14685, embedding size: 1536
# doc_id 5051361, embedding size: 1536
# doc_id 6865639, embedding size: 1536
# doc_id 284592, embedding size: 1536
# doc_id 72875, embedding size: 1536
# doc_id 1122294221, embedding size: 1536
# doc_id 1123765618, embedding size: 1536
# doc_id 6277862, embedding size: 1536
# doc_id 3028520, embedding size: 1536
# doc_id 536477, embedding size: 1536
# doc_id 179804, embedding size: 1536
# doc_id 616272, embedding size: 1536
# doc_id 281946, embedding size: 1536
# doc_id 6133217, embedding size: 1536
# doc_id 7823110, embedding size: 1536
# doc_id 14399204, embedding size: 1536
# doc_id 5495231, embedding size: 1536
# doc_id 6535790, embedding size: 1536
# doc_id 1121381929, embedding size: 1536
# doc_id 760892, embedding size: 1536
# doc_id 1547278, embedding size: 1536
# doc_id 4183237, embedding size: 1536
# doc_id 229284, embedding size: 1536
# doc_id 6293008, embedding size: 1536
# doc_id 3346871, embedding size: 1536
# doc_id 5384777, embedding size: 1536
# doc_id 6084433, embedding size: 1536
# doc_id 2525254, embedding size: 1536
# doc_id 4412077, embedding size: 1536
# doc_id 4372261, embedding size: 1536
# doc_id 15455362, embedding size: 1536
# doc_id 761199, embedding size: 1536
# doc_id 1122424352, embedding size: 1536
# doc_id 6064264, embedding size: 1536
# doc_id 392903669, embedding size: 1536
# doc_id 681216, embedding size: 1536
# doc_id 14704384, embedding size: 1536
# doc_id 649731592, embedding size: 1536
# doc_id 5994593, embedding size: 1536
# doc_id 1477571, embedding size: 1536
# doc_id 1124187772, embedding size: 1536
# doc_id 6278777, embedding size: 1536
# doc_id 399942, embedding size: 1536
# doc_id 6224628, embedding size: 1536
# doc_id 301706, embedding size: 1536
# doc_id 9235924, embedding size: 1536
# doc_id 1122877897, embedding size: 1536
# doc_id 4683021, embedding size: 1536
# doc_id 2004712, embedding size: 1536
# doc_id 6238712, embedding size: 1536
# doc_id 1363831, embedding size: 1536
# doc_id 5244127, embedding size: 1536
# doc_id 1606176, embedding size: 1536
# doc_id 4318090, embedding size: 1536
# doc_id 328071069, embedding size: 1536
# doc_id 23912, embedding size: 1536
# doc_id 399439398, embedding size: 1536
# doc_id 1136637, embedding size: 1536
# doc_id 2856278, embedding size: 1536
# doc_id 5341047, embedding size: 1536
# doc_id 6217139, embedding size: 1536
# doc_id 4873942, embedding size: 1536
# doc_id 4893912, embedding size: 1536
# doc_id 7745497, embedding size: 1536
# doc_id 1123963673, embedding size: 1536
# doc_id 417492157, embedding size: 1536
# doc_id 6222172, embedding size: 1536
# doc_id 3874823, embedding size: 1536
# doc_id 5083869, embedding size: 1536
# doc_id 391315040, embedding size: 1536
# doc_id 7549741, embedding size: 1536
# doc_id 2995558, embedding size: 1536
# doc_id 422579799, embedding size: 1536
# doc_id 14438129, embedding size: 1536
# doc_id 8349022, embedding size: 1536
# doc_id 1124098080, embedding size: 1536
# doc_id 337753, embedding size: 1536
# doc_id 5541977, embedding size: 1536
# doc_id 4354259, embedding size: 1536
# doc_id 16885443, embedding size: 1536
# doc_id 1121829454, embedding size: 1536
# doc_id 1123727333, embedding size: 1536
# doc_id 337906, embedding size: 1536
# doc_id 1123440578, embedding size: 1536
# doc_id 1121121707, embedding size: 1536
# doc_id 642485565, embedding size: 1536
# doc_id 1121566193, embedding size: 1536
# doc_id 1121271029, embedding size: 1536
# doc_id 730745, embedding size: 1536
# doc_id 1963845298, embedding size: 1536
# doc_id 1123974283, embedding size: 1536
# doc_id 7594440, embedding size: 1536
# doc_id 249915, embedding size: 1536
# doc_id 1123357201, embedding size: 1536
# doc_id 241231, embedding size: 1536
# doc_id 1121305528, embedding size: 1536
# doc_id 14940051, embedding size: 1536
# doc_id 1123595276, embedding size: 1536
# doc_id 1123699613, embedding size: 1536
# doc_id 1122963657, embedding size: 1536
# doc_id 129103434, embedding size: 1536
# doc_id 227842, embedding size: 1536
# doc_id 243344, embedding size: 1536
# doc_id 395842426, embedding size: 1536
# doc_id 1121344412, embedding size: 1536
# doc_id 215865685, embedding size: 1536
# doc_id 1962941443, embedding size: 1536
# doc_id 1965067743, embedding size: 1536
# doc_id 1964624017, embedding size: 1536
# doc_id 16888205, embedding size: 1536
# doc_id 130197846, embedding size: 1536
# doc_id 6243525, embedding size: 1536
# doc_id 736131, embedding size: 1536
# doc_id 329742, embedding size: 1536
# doc_id 682293, embedding size: 1536
# doc_id 5338465, embedding size: 1536
# doc_id 718782, embedding size: 1536
# doc_id 319749, embedding size: 1536
# doc_id 143156, embedding size: 1536
# doc_id 1021616, embedding size: 1536
# doc_id 436249, embedding size: 1536
# doc_id 5691801, embedding size: 1536
# doc_id 2350188, embedding size: 1536
# doc_id 84460, embedding size: 1536
# doc_id 730096, embedding size: 1536
# doc_id 14622995, embedding size: 1536
# doc_id 749121, embedding size: 1536
# doc_id 3796915, embedding size: 1536
# doc_id 2141190, embedding size: 1536
# doc_id 306417, embedding size: 1536
# doc_id 566192, embedding size: 1536
# doc_id 979918, embedding size: 1536
# doc_id 189326, embedding size: 1536
# doc_id 77825, embedding size: 1536
# doc_id 84337, embedding size: 1536
# doc_id 1275461, embedding size: 1536
# doc_id 602313, embedding size: 1536
# doc_id 1230584, embedding size: 1536
# doc_id 3869736, embedding size: 1536
# doc_id 4421244, embedding size: 1536
# doc_id 993268, embedding size: 1536
# doc_id 2778106, embedding size: 1536
# doc_id 675553, embedding size: 1536
# doc_id 741067, embedding size: 1536
# doc_id 6595282, embedding size: 1536
# doc_id 6352460, embedding size: 1536
# doc_id 14675650, embedding size: 1536
# doc_id 5152926, embedding size: 1536
# doc_id 775631, embedding size: 1536
# doc_id 95625, embedding size: 1536
# doc_id 544718, embedding size: 1536
# doc_id 14531386, embedding size: 1536
# doc_id 409600, embedding size: 1536
# doc_id 2156464, embedding size: 1536
# doc_id 416233, embedding size: 1536
# doc_id 861339, embedding size: 1536
# doc_id 17739465, embedding size: 1536
# doc_id 831571, embedding size: 1536
# doc_id 2370488, embedding size: 1536
# doc_id 1309, embedding size: 1536
# doc_id 733944, embedding size: 1536
# doc_id 4615152, embedding size: 1536
# doc_id 8174543, embedding size: 1536
# doc_id 34592, embedding size: 1536
# doc_id 541316, embedding size: 1536
# doc_id 186452, embedding size: 1536
# doc_id 6245821, embedding size: 1536
# doc_id 14320410, embedding size: 1536
# doc_id 914302, embedding size: 1536
# doc_id 6228904, embedding size: 1536
# doc_id 2830557, embedding size: 1536
# doc_id 636047, embedding size: 1536
# doc_id 988285, embedding size: 1536
# doc_id 512020, embedding size: 1536
# doc_id 567416, embedding size: 1536
# doc_id 427354, embedding size: 1536
# doc_id 69646, embedding size: 1536
# doc_id 789847, embedding size: 1536
# doc_id 255305, embedding size: 1536
# doc_id 226263, embedding size: 1536
# doc_id 715211, embedding size: 1536
# doc_id 390681, embedding size: 1536
# doc_id 3751566, embedding size: 1536
# doc_id 217152, embedding size: 1536
# doc_id 729386, embedding size: 1536
# doc_id 6360806, embedding size: 1536
# doc_id 6249686, embedding size: 1536
# doc_id 2053796, embedding size: 1536
# doc_id 7164, embedding size: 1536
# doc_id 3357421, embedding size: 1536
# doc_id 278229, embedding size: 1536
# doc_id 4062108, embedding size: 1536
# doc_id 942556, embedding size: 1536
# doc_id 600556, embedding size: 1536
# doc_id 30385, embedding size: 1536
# doc_id 210406, embedding size: 1536
# doc_id 6271231, embedding size: 1536
# doc_id 597325, embedding size: 1536
# doc_id 565753, embedding size: 1536
# doc_id 1922466, embedding size: 1536
# doc_id 685447, embedding size: 1536
# doc_id 660324, embedding size: 1536
# doc_id 54882, embedding size: 1536
# doc_id 3963229, embedding size: 1536
# doc_id 4705303, embedding size: 1536
# doc_id 4413885, embedding size: 1536
# doc_id 359019, embedding size: 1536
# doc_id 929186, embedding size: 1536
# doc_id 504183, embedding size: 1536
# doc_id 2089987, embedding size: 1536
# doc_id 219774, embedding size: 1536
# doc_id 21066, embedding size: 1536
# doc_id 332290, embedding size: 1536
# doc_id 305347, embedding size: 1536
# doc_id 581866, embedding size: 1536
# doc_id 16799332, embedding size: 1536
# doc_id 756057, embedding size: 1536
# doc_id 6605960, embedding size: 1536
# doc_id 14681004, embedding size: 1536
# doc_id 1986060, embedding size: 1536
# doc_id 6357621, embedding size: 1536
# doc_id 410444244, embedding size: 1536
# doc_id 172706, embedding size: 1536
# doc_id 401701171, embedding size: 1536
# doc_id 14680969, embedding size: 1536
# doc_id 8279672, embedding size: 1536
# doc_id 33673, embedding size: 1536
# doc_id 14742817, embedding size: 1536
# doc_id 5225161, embedding size: 1536
# doc_id 2881725, embedding size: 1536
# doc_id 7571133, embedding size: 1536
# doc_id 3732674, embedding size: 1536
# doc_id 7992555, embedding size: 1536
# doc_id 686599, embedding size: 1536
# doc_id 14584646, embedding size: 1536
# doc_id 4325726, embedding size: 1536
# doc_id 775697, embedding size: 1536
# doc_id 268765, embedding size: 1536
# doc_id 2064616, embedding size: 1536
# doc_id 919707, embedding size: 1536
# doc_id 5050267, embedding size: 1536
# doc_id 2743179, embedding size: 1536
# doc_id 4556552, embedding size: 1536
# doc_id 315194, embedding size: 1536
# doc_id 412932, embedding size: 1536
# doc_id 23213015, embedding size: 1536
# doc_id 146224, embedding size: 1536
# doc_id 652884, embedding size: 1536
# doc_id 509333, embedding size: 1536
# doc_id 4250409, embedding size: 1536
# doc_id 14577336, embedding size: 1536
# doc_id 215861258, embedding size: 1536
# doc_id 19795438, embedding size: 1536
# doc_id 18890, embedding size: 1536
# doc_id 4973589, embedding size: 1536
# doc_id 34969, embedding size: 1536
# doc_id 2942454, embedding size: 1536
# doc_id 2596310, embedding size: 1536
# doc_id 702170, embedding size: 1536
# doc_id 2657449, embedding size: 1536
# doc_id 8003503, embedding size: 1536
# doc_id 6637097, embedding size: 1536
# doc_id 15476265, embedding size: 1536
# doc_id 6007947, embedding size: 1536
# doc_id 439462, embedding size: 1536
# doc_id 2592954, embedding size: 1536
# doc_id 3707556, embedding size: 1536
# doc_id 246131, embedding size: 1536
# doc_id 63673, embedding size: 1536
# doc_id 3229247, embedding size: 1536
# doc_id 2138020, embedding size: 1536
# doc_id 546679, embedding size: 1536
# doc_id 5922491, embedding size: 1536
# doc_id 7045613, embedding size: 1536
# doc_id 5727, embedding size: 1536
# doc_id 395333, embedding size: 1536
# doc_id 16659820, embedding size: 1536
# doc_id 6099946, embedding size: 1536
# doc_id 1205043, embedding size: 1536
# doc_id 14578966, embedding size: 1536
# doc_id 215860547, embedding size: 1536
# doc_id 17410664, embedding size: 1536
# doc_id 5930116, embedding size: 1536
# doc_id 168980, embedding size: 1536
# doc_id 5138288, embedding size: 1536
# doc_id 14595276, embedding size: 1536
# doc_id 907337, embedding size: 1536
# doc_id 1337608, embedding size: 1536
# doc_id 27083, embedding size: 1536
# doc_id 1123077812, embedding size: 1536
# doc_id 2959129, embedding size: 1536
# doc_id 7058634, embedding size: 1536
# doc_id 347964435, embedding size: 1536
# doc_id 8083465, embedding size: 1536
# doc_id 7842848, embedding size: 1536
# doc_id 13075, embedding size: 1536
# doc_id 2592650, embedding size: 1536
# doc_id 8343507, embedding size: 1536
# doc_id 6108481, embedding size: 1536
# doc_id 6429363, embedding size: 1536
# doc_id 1128478, embedding size: 1536
# doc_id 4437148, embedding size: 1536
# doc_id 16741022, embedding size: 1536
# doc_id 2062250, embedding size: 1536
# doc_id 87494, embedding size: 1536
# doc_id 1301854, embedding size: 1536
# doc_id 1123399196, embedding size: 1536
# doc_id 856272, embedding size: 1536
# doc_id 6430235, embedding size: 1536
# doc_id 392720325, embedding size: 1536
# doc_id 2792735, embedding size: 1536
# doc_id 773950, embedding size: 1536
# doc_id 198314, embedding size: 1536
# doc_id 198688, embedding size: 1536
# doc_id 639250488, embedding size: 1536
# doc_id 3322910, embedding size: 1536
# doc_id 2691164, embedding size: 1536
# doc_id 16963724, embedding size: 1536
# doc_id 1123666458, embedding size: 1536
# doc_id 419867039, embedding size: 1536
# doc_id 3056489, embedding size: 1536
# doc_id 1121960270, embedding size: 1536
# doc_id 2851875, embedding size: 1536
# doc_id 1121229708, embedding size: 1536
# doc_id 1627582047, embedding size: 1536
# doc_id 894315, embedding size: 1536
# doc_id 2377398, embedding size: 1536
# doc_id 6521783, embedding size: 1536
# doc_id 6260050, embedding size: 1536
# doc_id 1121321687, embedding size: 1536
# doc_id 1121225744, embedding size: 1536
# doc_id 6252930, embedding size: 1536
# doc_id 1121216899, embedding size: 1536
# doc_id 1121068804, embedding size: 1536
# doc_id 1123960085, embedding size: 1536
# doc_id 4906462, embedding size: 1536
# doc_id 1121782601, embedding size: 1536
# doc_id 1122370449, embedding size: 1536
# doc_id 639425764, embedding size: 1536
# doc_id 6313952, embedding size: 1536
# doc_id 1121328212, embedding size: 1536
# doc_id 14404815, embedding size: 1536
# doc_id 1121387567, embedding size: 1536
# doc_id 14411347, embedding size: 1536
# doc_id 1121376208, embedding size: 1536
# doc_id 7973314, embedding size: 1536
# doc_id 1124092017, embedding size: 1536
# doc_id 1033471, embedding size: 1536
# doc_id 639257295, embedding size: 1536
# doc_id 1123942502, embedding size: 1536
# doc_id 1123660433, embedding size: 1536
# doc_id 1123603920, embedding size: 1536
# doc_id 870950040, embedding size: 1536
# doc_id 1123831941, embedding size: 1536
# doc_id 1123382205, embedding size: 1536
# doc_id 1124091451, embedding size: 1536
# doc_id 14426899, embedding size: 1536
# doc_id 18203183, embedding size: 1536
# doc_id 279939, embedding size: 1536
# doc_id 23243075, embedding size: 1536
# doc_id 40861, embedding size: 1536
# doc_id 5198340, embedding size: 1536
# doc_id 303368, embedding size: 1536
# doc_id 300757, embedding size: 1536
# doc_id 6859298, embedding size: 1536
# doc_id 297243, embedding size: 1536
# doc_id 401313288, embedding size: 1536
# doc_id 14342668, embedding size: 1536
# doc_id 2166030, embedding size: 1536
# doc_id 1280429, embedding size: 1536
# doc_id 423898, embedding size: 1536
# doc_id 14514356, embedding size: 1536
# doc_id 7927807, embedding size: 1536
# doc_id 543909, embedding size: 1536
# doc_id 3447283, embedding size: 1536
# doc_id 514693, embedding size: 1536
# doc_id 874014, embedding size: 1536
# doc_id 693886, embedding size: 1536
# doc_id 926046, embedding size: 1536
# doc_id 205241, embedding size: 1536
# doc_id 578712, embedding size: 1536
# doc_id 19437391, embedding size: 1536
# doc_id 762846, embedding size: 1536
# doc_id 2091179, embedding size: 1536
# doc_id 3998527, embedding size: 1536
# doc_id 182194, embedding size: 1536
# doc_id 753006, embedding size: 1536
# doc_id 275235, embedding size: 1536
# doc_id 2249213, embedding size: 1536
# doc_id 2044732, embedding size: 1536
# doc_id 1123285445, embedding size: 1536
# doc_id 2864393, embedding size: 1536
# doc_id 506470, embedding size: 1536
# doc_id 6083625, embedding size: 1536
# doc_id 645711, embedding size: 1536
# doc_id 146770, embedding size: 1536
# doc_id 147485, embedding size: 1536
# doc_id 2381081, embedding size: 1536
# doc_id 14710843, embedding size: 1536
# doc_id 1088832, embedding size: 1536
# doc_id 3710774, embedding size: 1536
# doc_id 1077536, embedding size: 1536
# doc_id 285603, embedding size: 1536
# doc_id 853260, embedding size: 1536
# doc_id 14695015, embedding size: 1536
# doc_id 672688, embedding size: 1536
# doc_id 292346, embedding size: 1536
# doc_id 944910, embedding size: 1536
# doc_id 723416, embedding size: 1536
# doc_id 148492, embedding size: 1536
# doc_id 14749659, embedding size: 1536
# doc_id 406926, embedding size: 1536
# doc_id 2942, embedding size: 1536
# doc_id 8337195, embedding size: 1536
# doc_id 3304890, embedding size: 1536
# doc_id 707023, embedding size: 1536
# doc_id 611703, embedding size: 1536
# doc_id 148996, embedding size: 1536
# doc_id 1762476, embedding size: 1536
# doc_id 2097224, embedding size: 1536
# doc_id 856794, embedding size: 1536
# doc_id 831091, embedding size: 1536
# doc_id 3603969, embedding size: 1536
# doc_id 775866, embedding size: 1536
# doc_id 64316, embedding size: 1536
# doc_id 676572, embedding size: 1536
# doc_id 48813, embedding size: 1536
# doc_id 45894, embedding size: 1536
# doc_id 332491, embedding size: 1536
# doc_id 14711944, embedding size: 1536
# doc_id 750687, embedding size: 1536
# doc_id 4019286, embedding size: 1536
# doc_id 615290, embedding size: 1536
# doc_id 196019, embedding size: 1536
# doc_id 3877504, embedding size: 1536
# doc_id 3421695, embedding size: 1536
# doc_id 3440006, embedding size: 1536
# doc_id 411828940, embedding size: 1536
# doc_id 375627, embedding size: 1536
# doc_id 4099783, embedding size: 1536
# doc_id 780709, embedding size: 1536
# doc_id 422275239, embedding size: 1536
# doc_id 130985, embedding size: 1536
# doc_id 6243928, embedding size: 1536
# doc_id 6216002, embedding size: 1536
# doc_id 689029, embedding size: 1536
# doc_id 468460071, embedding size: 1536
# doc_id 809623, embedding size: 1536
# doc_id 16859532, embedding size: 1536
# doc_id 2712129, embedding size: 1536
# doc_id 523320, embedding size: 1536
# doc_id 593896, embedding size: 1536
# doc_id 755647, embedding size: 1536
# doc_id 494721, embedding size: 1536
# doc_id 4307875, embedding size: 1536
# doc_id 244551, embedding size: 1536
# doc_id 2614201, embedding size: 1536
# doc_id 3958012, embedding size: 1536
# doc_id 683527, embedding size: 1536
# doc_id 33010, embedding size: 1536
# doc_id 104639, embedding size: 1536
# doc_id 5161117, embedding size: 1536
# doc_id 159824, embedding size: 1536
# doc_id 5455461, embedding size: 1536
# doc_id 6386821, embedding size: 1536
# doc_id 989924, embedding size: 1536
# doc_id 746533, embedding size: 1536
# doc_id 303377, embedding size: 1536
# doc_id 4760613, embedding size: 1536
# doc_id 33918, embedding size: 1536
# doc_id 14620446, embedding size: 1536
# doc_id 51778, embedding size: 1536
# doc_id 7734489, embedding size: 1536
# doc_id 596361, embedding size: 1536
# doc_id 241225, embedding size: 1536
# doc_id 14484631, embedding size: 1536
# doc_id 5503610, embedding size: 1536
# doc_id 5546359, embedding size: 1536
# doc_id 115848, embedding size: 1536
# doc_id 787723, embedding size: 1536
# doc_id 152024, embedding size: 1536
# doc_id 4946759, embedding size: 1536
# doc_id 2175885, embedding size: 1536
# doc_id 549746, embedding size: 1536
# doc_id 183175, embedding size: 1536
# doc_id 939486, embedding size: 1536
# doc_id 2775140, embedding size: 1536
# doc_id 5031701, embedding size: 1536
# doc_id 6415666, embedding size: 1536
# doc_id 733231, embedding size: 1536
# doc_id 15836, embedding size: 1536
# doc_id 143311, embedding size: 1536
# doc_id 125844, embedding size: 1536
# doc_id 6154125, embedding size: 1536
# doc_id 2024210, embedding size: 1536
# doc_id 4727371, embedding size: 1536
# doc_id 137960287, embedding size: 1536
# doc_id 29501, embedding size: 1536
# doc_id 343256, embedding size: 1536
# doc_id 639491796, embedding size: 1536
# doc_id 421081, embedding size: 1536
# doc_id 375689, embedding size: 1536
# doc_id 54978, embedding size: 1536
# doc_id 322438527, embedding size: 1536
# doc_id 578763, embedding size: 1536
# doc_id 4104192, embedding size: 1536
# doc_id 5146654, embedding size: 1536
# doc_id 726739, embedding size: 1536
# doc_id 72183, embedding size: 1536
# doc_id 5373874, embedding size: 1536
# doc_id 497484, embedding size: 1536
# doc_id 788543, embedding size: 1536
# doc_id 1046340, embedding size: 1536
# doc_id 1603568, embedding size: 1536
# doc_id 517131, embedding size: 1536
# doc_id 47523, embedding size: 1536
# doc_id 2132057, embedding size: 1536
# doc_id 19286753, embedding size: 1536
# doc_id 2754963, embedding size: 1536
# doc_id 4378512, embedding size: 1536
# doc_id 2988582, embedding size: 1536
# doc_id 6447309, embedding size: 1536
# doc_id 9018274, embedding size: 1536
# doc_id 557342, embedding size: 1536
# doc_id 1123954848, embedding size: 1536
# doc_id 3409757, embedding size: 1536
# doc_id 8328734, embedding size: 1536
# doc_id 2753694, embedding size: 1536
# doc_id 7888554, embedding size: 1536
# doc_id 619261, embedding size: 1536
# doc_id 2065040, embedding size: 1536
# doc_id 4437218, embedding size: 1536
# doc_id 409340, embedding size: 1536
# doc_id 2245851, embedding size: 1536
# doc_id 560302, embedding size: 1536
# doc_id 4783482, embedding size: 1536
# doc_id 3736, embedding size: 1536
# doc_id 6291048, embedding size: 1536
# doc_id 733828, embedding size: 1536
# doc_id 7971888, embedding size: 1536
# doc_id 1466211, embedding size: 1536
# doc_id 139420, embedding size: 1536
# doc_id 385051, embedding size: 1536
# doc_id 1146562, embedding size: 1536
# doc_id 300163, embedding size: 1536
# doc_id 2031273, embedding size: 1536
# doc_id 2215888, embedding size: 1536
# doc_id 112161, embedding size: 1536
# doc_id 656414, embedding size: 1536
# doc_id 6238697, embedding size: 1536
# doc_id 521276, embedding size: 1536
# doc_id 6284016, embedding size: 1536
# doc_id 5089930, embedding size: 1536
# doc_id 2206593, embedding size: 1536
# doc_id 928419, embedding size: 1536
# doc_id 3988932, embedding size: 1536
# doc_id 771385, embedding size: 1536
# doc_id 14592301, embedding size: 1536
# doc_id 424872, embedding size: 1536
# doc_id 1694903, embedding size: 1536
# doc_id 130491412, embedding size: 1536
# doc_id 130478585, embedding size: 1536
# doc_id 72766, embedding size: 1536
# doc_id 5304325, embedding size: 1536
# doc_id 5458702, embedding size: 1536
# doc_id 2054044, embedding size: 1536
# doc_id 731510, embedding size: 1536
# doc_id 535084, embedding size: 1536
# doc_id 3094749, embedding size: 1536
# doc_id 3106676, embedding size: 1536
# doc_id 838405604, embedding size: 1536
# doc_id 2093809, embedding size: 1536
# doc_id 2032374, embedding size: 1536
# doc_id 6150191, embedding size: 1536
# doc_id 6514442, embedding size: 1536
# doc_id 5952686, embedding size: 1536
# doc_id 2561933, embedding size: 1536
# doc_id 4385819, embedding size: 1536
# doc_id 3162610, embedding size: 1536
# doc_id 4002970, embedding size: 1536
# doc_id 783909, embedding size: 1536
# doc_id 6157346, embedding size: 1536
# doc_id 8302311, embedding size: 1536
# doc_id 4322085, embedding size: 1536
# doc_id 725574, embedding size: 1536
# doc_id 199251, embedding size: 1536
# doc_id 6211638, embedding size: 1536
# doc_id 2928661, embedding size: 1536
# doc_id 9471, embedding size: 1536
# doc_id 7363246, embedding size: 1536
# doc_id 2231840, embedding size: 1536
# doc_id 1222451, embedding size: 1536
# doc_id 35460, embedding size: 1536
# doc_id 5391845, embedding size: 1536
# doc_id 14379830, embedding size: 1536
# doc_id 6264107, embedding size: 1536
# doc_id 5690446, embedding size: 1536
# doc_id 430189, embedding size: 1536
# doc_id 1057818, embedding size: 1536
# doc_id 4596394, embedding size: 1536
# doc_id 783925, embedding size: 1536
# doc_id 791145, embedding size: 1536
# doc_id 6766813, embedding size: 1536
# doc_id 525085, embedding size: 1536
# doc_id 1561475, embedding size: 1536
# doc_id 456545, embedding size: 1536
# doc_id 131312018, embedding size: 1536
# doc_id 1310300, embedding size: 1536
# doc_id 743845, embedding size: 1536
# doc_id 5290432, embedding size: 1536
# doc_id 9194066, embedding size: 1536
# doc_id 5381149, embedding size: 1536
# doc_id 1121350977, embedding size: 1536
# doc_id 1702830, embedding size: 1536
# doc_id 247059, embedding size: 1536
# doc_id 16954128, embedding size: 1536
# doc_id 6165378, embedding size: 1536
# doc_id 6319099, embedding size: 1536
# doc_id 112502, embedding size: 1536
# doc_id 12233, embedding size: 1536
# doc_id 513473, embedding size: 1536
# doc_id 518942, embedding size: 1536
# doc_id 487004, embedding size: 1536
# doc_id 395229024, embedding size: 1536
# doc_id 15178, embedding size: 1536
# doc_id 406047678, embedding size: 1536
# doc_id 424696363, embedding size: 1536
# doc_id 5058104, embedding size: 1536
# doc_id 2425355, embedding size: 1536
# doc_id 2247163, embedding size: 1536
# doc_id 1121551111, embedding size: 1536
# doc_id 391320543, embedding size: 1536
# doc_id 1373213, embedding size: 1536
# doc_id 408566, embedding size: 1536
# doc_id 515564, embedding size: 1536
# doc_id 8632992, embedding size: 1536
# doc_id 4318448, embedding size: 1536
# doc_id 427381589, embedding size: 1536
# doc_id 1123821585, embedding size: 1536
# doc_id 6605975, embedding size: 1536
# doc_id 1121538880, embedding size: 1536
# doc_id 270813, embedding size: 1536
# doc_id 1017719, embedding size: 1536
# doc_id 14695791, embedding size: 1536
# doc_id 1121929062, embedding size: 1536
# doc_id 8699891, embedding size: 1536
# doc_id 6588337, embedding size: 1536
# doc_id 742695, embedding size: 1536
# doc_id 5235, embedding size: 1536
# doc_id 6197882, embedding size: 1536
# doc_id 7249676, embedding size: 1536
# doc_id 1124144555, embedding size: 1536
# doc_id 18211893, embedding size: 1536
# doc_id 6868102, embedding size: 1536
# doc_id 19540, embedding size: 1536
# doc_id 130548386, embedding size: 1536
# doc_id 1123746972, embedding size: 1536
# doc_id 1122248376, embedding size: 1536
# doc_id 395182227, embedding size: 1536
# doc_id 1123018605, embedding size: 1536
# doc_id 639297136, embedding size: 1536
# doc_id 1124183861, embedding size: 1536
# doc_id 1725778291, embedding size: 1536
# doc_id 639310952, embedding size: 1536
# doc_id 640147399, embedding size: 1536
# doc_id 393997175, embedding size: 1536
# doc_id 37987, embedding size: 1536
# doc_id 62078, embedding size: 1536
# doc_id 6244002, embedding size: 1536
# doc_id 530871, embedding size: 1536
# doc_id 736872, embedding size: 1536
# doc_id 231914, embedding size: 1536
# doc_id 3795594, embedding size: 1536
# doc_id 17405544, embedding size: 1536
# doc_id 595625, embedding size: 1536
# doc_id 2360903, embedding size: 1536
# doc_id 30189, embedding size: 1536
# doc_id 642306, embedding size: 1536
# doc_id 99205, embedding size: 1536
# doc_id 532953, embedding size: 1536
# doc_id 706839, embedding size: 1536
# doc_id 68590, embedding size: 1536
# doc_id 602431, embedding size: 1536
# doc_id 80612, embedding size: 1536
# doc_id 5642416, embedding size: 1536
# doc_id 671946, embedding size: 1536
# doc_id 5115226, embedding size: 1536
# doc_id 7924150, embedding size: 1536
# doc_id 2047419, embedding size: 1536
# doc_id 1124089732, embedding size: 1536
# doc_id 1122292759, embedding size: 1536
# doc_id 3782132, embedding size: 1536
# doc_id 479364, embedding size: 1536
# doc_id 3441816, embedding size: 1536
# doc_id 759678, embedding size: 1536
# doc_id 601154, embedding size: 1536
# doc_id 5016995, embedding size: 1536
# doc_id 2029482, embedding size: 1536
# doc_id 915016, embedding size: 1536
# doc_id 1010329, embedding size: 1536
# doc_id 592184, embedding size: 1536
# doc_id 371660, embedding size: 1536
# doc_id 931675, embedding size: 1536
# doc_id 14986194, embedding size: 1536
# doc_id 750228, embedding size: 1536
# doc_id 725699, embedding size: 1536
# doc_id 59599, embedding size: 1536
# doc_id 512023, embedding size: 1536
# doc_id 6168834, embedding size: 1536
# doc_id 2293619, embedding size: 1536
# doc_id 195998, embedding size: 1536
# doc_id 124365, embedding size: 1536
# doc_id 5008861, embedding size: 1536
# doc_id 2775080, embedding size: 1536
# doc_id 4935156, embedding size: 1536
# doc_id 6232912, embedding size: 1536
# doc_id 131078, embedding size: 1536
# doc_id 2231034, embedding size: 1536
# doc_id 614910, embedding size: 1536
# doc_id 3704148, embedding size: 1536
# doc_id 37116, embedding size: 1536
# doc_id 324014, embedding size: 1536
# doc_id 4342776, embedding size: 1536
# doc_id 626621, embedding size: 1536
# doc_id 738083, embedding size: 1536
# doc_id 2021424, embedding size: 1536
# doc_id 5557266, embedding size: 1536
# doc_id 6258155, embedding size: 1536
# doc_id 15849441, embedding size: 1536
# doc_id 7895125, embedding size: 1536
# doc_id 157390, embedding size: 1536
# doc_id 2228093, embedding size: 1536
# doc_id 347318, embedding size: 1536
# doc_id 2082073, embedding size: 1536
# doc_id 3655597, embedding size: 1536
# doc_id 8583244, embedding size: 1536
# doc_id 202311, embedding size: 1536
# doc_id 8074675, embedding size: 1536
# doc_id 111167, embedding size: 1536
# doc_id 177000, embedding size: 1536
# doc_id 677368, embedding size: 1536
# doc_id 2780804, embedding size: 1536
# doc_id 3876127, embedding size: 1536
# doc_id 538003, embedding size: 1536
# doc_id 521391, embedding size: 1536
# doc_id 3051094, embedding size: 1536
# doc_id 579992, embedding size: 1536
# doc_id 645276, embedding size: 1536
# doc_id 14716717, embedding size: 1536
# doc_id 960109, embedding size: 1536
# doc_id 7980, embedding size: 1536
# doc_id 331946, embedding size: 1536
# doc_id 2023071, embedding size: 1536
# doc_id 603693, embedding size: 1536
# doc_id 8043, embedding size: 1536
# doc_id 14562066, embedding size: 1536
# doc_id 4286104, embedding size: 1536
# doc_id 4796651, embedding size: 1536
# doc_id 1123817966, embedding size: 1536
# doc_id 593590, embedding size: 1536
# doc_id 6189511, embedding size: 1536
# doc_id 3742852, embedding size: 1536
# doc_id 4947529, embedding size: 1536
# doc_id 2617644, embedding size: 1536
# doc_id 6099709, embedding size: 1536
# doc_id 282145, embedding size: 1536
# doc_id 542389, embedding size: 1536
# doc_id 101307, embedding size: 1536
# doc_id 2033926, embedding size: 1536
# doc_id 444509, embedding size: 1536
# doc_id 1121570647, embedding size: 1536
# doc_id 6234542, embedding size: 1536
# doc_id 143335, embedding size: 1536
# doc_id 6224857, embedding size: 1536
# doc_id 73101, embedding size: 1536
# doc_id 6544025, embedding size: 1536
# doc_id 870986336, embedding size: 1536
# doc_id 2089869, embedding size: 1536
# doc_id 5086939, embedding size: 1536
# doc_id 700869, embedding size: 1536
# doc_id 6064643, embedding size: 1536
# doc_id 740071, embedding size: 1536
# doc_id 6279574, embedding size: 1536
# doc_id 23001, embedding size: 1536
# doc_id 146996, embedding size: 1536
# doc_id 1178997, embedding size: 1536
# doc_id 4678158, embedding size: 1536
# doc_id 338928, embedding size: 1536
# doc_id 499513, embedding size: 1536
# doc_id 3675132, embedding size: 1536
# doc_id 17785921, embedding size: 1536
# doc_id 4949723, embedding size: 1536
# doc_id 18285250, embedding size: 1536
# doc_id 54355, embedding size: 1536
# doc_id 10975, embedding size: 1536
# doc_id 1005421, embedding size: 1536
# doc_id 1088116, embedding size: 1536
# doc_id 2452723, embedding size: 1536
# doc_id 1123678515, embedding size: 1536
# doc_id 6326382, embedding size: 1536
# doc_id 14544982, embedding size: 1536
# doc_id 4025832, embedding size: 1536
# doc_id 510126, embedding size: 1536
# doc_id 6343201, embedding size: 1536
# doc_id 8230434, embedding size: 1536
# doc_id 5011947, embedding size: 1536
# doc_id 249086, embedding size: 1536
# doc_id 2958398, embedding size: 1536
# doc_id 4660660, embedding size: 1536
# doc_id 874028, embedding size: 1536
# doc_id 4493983, embedding size: 1536
# doc_id 14552581, embedding size: 1536
# doc_id 5154838, embedding size: 1536
# doc_id 262335, embedding size: 1536
# doc_id 1121787762, embedding size: 1536
# doc_id 196345, embedding size: 1536
# doc_id 5184069, embedding size: 1536
# doc_id 2346684, embedding size: 1536
# doc_id 4311164, embedding size: 1536
# doc_id 5008368, embedding size: 1536
# doc_id 731023, embedding size: 1536
# doc_id 8095182, embedding size: 1536
# doc_id 1588679, embedding size: 1536
# doc_id 4716375, embedding size: 1536
# doc_id 4270377, embedding size: 1536
# doc_id 4388526, embedding size: 1536
# doc_id 1121509776, embedding size: 1536
# doc_id 666025, embedding size: 1536
# doc_id 14682628, embedding size: 1536
# doc_id 1045, embedding size: 1536
# doc_id 2240758, embedding size: 1536
# doc_id 1121572252, embedding size: 1536
# doc_id 847827, embedding size: 1536
# doc_id 6310295, embedding size: 1536
# doc_id 19181856, embedding size: 1536
# doc_id 2591052, embedding size: 1536
# doc_id 582138, embedding size: 1536
# doc_id 4360209, embedding size: 1536
# doc_id 2762074, embedding size: 1536
# doc_id 161547, embedding size: 1536
# doc_id 1121493643, embedding size: 1536
# doc_id 1123399446, embedding size: 1536
# doc_id 5702112, embedding size: 1536
# doc_id 6171703, embedding size: 1536
# doc_id 1901248, embedding size: 1536
# doc_id 936567, embedding size: 1536
# doc_id 6300497, embedding size: 1536
# doc_id 8852516, embedding size: 1536
# doc_id 462332, embedding size: 1536
# doc_id 1123638110, embedding size: 1536
# doc_id 6514509, embedding size: 1536
# doc_id 1431685, embedding size: 1536
# doc_id 2234721, embedding size: 1536
# doc_id 5090136, embedding size: 1536
# doc_id 392870875, embedding size: 1536
# doc_id 9031, embedding size: 1536
# doc_id 3250636, embedding size: 1536
# doc_id 15268430, embedding size: 1536
# doc_id 321947, embedding size: 1536
# doc_id 5091737, embedding size: 1536
# doc_id 225726, embedding size: 1536
# doc_id 129113527, embedding size: 1536
# doc_id 5039257, embedding size: 1536
# doc_id 1121089700, embedding size: 1536
# doc_id 35001, embedding size: 1536
# doc_id 8116642, embedding size: 1536
# doc_id 640131760, embedding size: 1536
# doc_id 6998360, embedding size: 1536
# doc_id 391469850, embedding size: 1536
# doc_id 527317, embedding size: 1536
# doc_id 5700167, embedding size: 1536
# doc_id 4338386, embedding size: 1536
# doc_id 7160, embedding size: 1536
# doc_id 399324784, embedding size: 1536
# doc_id 4976, embedding size: 1536
# doc_id 2934977, embedding size: 1536
# doc_id 8344624, embedding size: 1536
# doc_id 9698, embedding size: 1536
# doc_id 1122421377, embedding size: 1536
# doc_id 640186219, embedding size: 1536
# doc_id 1121943193, embedding size: 1536
# doc_id 1639646284, embedding size: 1536
# doc_id 1123666636, embedding size: 1536
# doc_id 1123298165, embedding size: 1536
# doc_id 392867885, embedding size: 1536
# doc_id 1068013, embedding size: 1536
# doc_id 926855013, embedding size: 1536
# doc_id 53720, embedding size: 1536
# doc_id 1123359014, embedding size: 1536
# doc_id 1122000913, embedding size: 1536
# doc_id 13363, embedding size: 1536
# doc_id 1121296056, embedding size: 1536
# doc_id 16730683, embedding size: 1536
# doc_id 1122542478, embedding size: 1536
# doc_id 640183341, embedding size: 1536
# doc_id 6143731, embedding size: 1536
# doc_id 1961478811, embedding size: 1536
# doc_id 639295774, embedding size: 1536
# doc_id 1124184004, embedding size: 1536
# doc_id 1378606967, embedding size: 1536
# doc_id 814863, embedding size: 1536
# doc_id 6232133, embedding size: 1536
# doc_id 2994542, embedding size: 1536
# doc_id 61142, embedding size: 1536
# doc_id 6265327, embedding size: 1536
# doc_id 8155846, embedding size: 1536
# doc_id 933203, embedding size: 1536
# doc_id 636513, embedding size: 1536
# doc_id 28162, embedding size: 1536
# doc_id 6775336, embedding size: 1536
# doc_id 3949927, embedding size: 1536
# doc_id 639898537, embedding size: 1536
# doc_id 150524, embedding size: 1536
# doc_id 4094315, embedding size: 1536
# doc_id 567480, embedding size: 1536
# doc_id 36081, embedding size: 1536
# doc_id 393945871, embedding size: 1536
# doc_id 1124134714, embedding size: 1536
# doc_id 2098041, embedding size: 1536
# doc_id 606463, embedding size: 1536
# doc_id 48096, embedding size: 1536
# doc_id 595499, embedding size: 1536
# doc_id 25830, embedding size: 1536
# doc_id 743224, embedding size: 1536
# doc_id 14592128, embedding size: 1536
# doc_id 5374586, embedding size: 1536
# doc_id 91189, embedding size: 1536
# doc_id 7837116, embedding size: 1536
# doc_id 3427658, embedding size: 1536
# doc_id 53159, embedding size: 1536
# doc_id 885474, embedding size: 1536
# doc_id 7060800, embedding size: 1536
# doc_id 2076320, embedding size: 1536
# doc_id 6204632, embedding size: 1536
# doc_id 4860191, embedding size: 1536
# doc_id 5018423, embedding size: 1536
# doc_id 2786300, embedding size: 1536
# doc_id 2433556, embedding size: 1536
# doc_id 2814410, embedding size: 1536
# doc_id 3229082, embedding size: 1536
# doc_id 6316243, embedding size: 1536
# doc_id 2154645, embedding size: 1536
# doc_id 4458907, embedding size: 1536
# doc_id 4958962, embedding size: 1536
# doc_id 6291540, embedding size: 1536
# doc_id 1121084723, embedding size: 1536
# doc_id 4677694, embedding size: 1536
# doc_id 1121238629, embedding size: 1536
# doc_id 6320187, embedding size: 1536
# doc_id 4206313, embedding size: 1536
# doc_id 1123948127, embedding size: 1536
# doc_id 2246352, embedding size: 1536
# doc_id 3916875, embedding size: 1536
# doc_id 4403431, embedding size: 1536
# doc_id 14567350, embedding size: 1536
# doc_id 86632, embedding size: 1536
# doc_id 328040302, embedding size: 1536
# doc_id 2214745, embedding size: 1536
# doc_id 287821, embedding size: 1536
# doc_id 117435, embedding size: 1536
# doc_id 5544207, embedding size: 1536
# doc_id 8566168, embedding size: 1536
# doc_id 4585613, embedding size: 1536
# doc_id 135161, embedding size: 1536
# doc_id 4254278, embedding size: 1536
# doc_id 6154512, embedding size: 1536
# doc_id 14348273, embedding size: 1536
# doc_id 130189638, embedding size: 1536
# doc_id 5367449, embedding size: 1536
# doc_id 374240, embedding size: 1536
# doc_id 5668706, embedding size: 1536
# doc_id 2340427, embedding size: 1536
# doc_id 16430123, embedding size: 1536
# doc_id 8978241, embedding size: 1536
# doc_id 4388901, embedding size: 1536
# doc_id 960371, embedding size: 1536
# doc_id 411245475, embedding size: 1536
# doc_id 6084461, embedding size: 1536
# doc_id 6255252, embedding size: 1536
# doc_id 6959398, embedding size: 1536
# doc_id 4188454, embedding size: 1536
# doc_id 405378, embedding size: 1536
# doc_id 5855173, embedding size: 1536
# doc_id 5096051, embedding size: 1536
# doc_id 1141154, embedding size: 1536
# doc_id 15582387, embedding size: 1536
# doc_id 14518008, embedding size: 1536
# doc_id 5082569, embedding size: 1536
# doc_id 6644509, embedding size: 1536
# doc_id 1124159263, embedding size: 1536
# doc_id 1343614, embedding size: 1536
# doc_id 5044709, embedding size: 1536
# doc_id 6281678, embedding size: 1536
# doc_id 4067059, embedding size: 1536
# doc_id 1289000, embedding size: 1536
# doc_id 1351490, embedding size: 1536
# doc_id 8036565, embedding size: 1536
# doc_id 14559411, embedding size: 1536
# doc_id 4393217, embedding size: 1536
# doc_id 2273181, embedding size: 1536
# doc_id 3651304, embedding size: 1536
# doc_id 8636456, embedding size: 1536
# doc_id 4392802, embedding size: 1536
# doc_id 7043842, embedding size: 1536
# doc_id 287849, embedding size: 1536
# doc_id 259400, embedding size: 1536
# doc_id 145053, embedding size: 1536
# doc_id 292869, embedding size: 1536
# doc_id 6327525, embedding size: 1536
# doc_id 589005, embedding size: 1536
# doc_id 982979, embedding size: 1536
# doc_id 743838, embedding size: 1536
# doc_id 639463959, embedding size: 1536
# doc_id 1588933, embedding size: 1536
# doc_id 6857069, embedding size: 1536
# doc_id 2584, embedding size: 1536
# doc_id 929333, embedding size: 1536
# doc_id 4416619, embedding size: 1536
# doc_id 6290305, embedding size: 1536
# doc_id 6103106, embedding size: 1536
# doc_id 1124148541, embedding size: 1536
# doc_id 6345593, embedding size: 1536
# doc_id 1712965, embedding size: 1536
# doc_id 1121892327, embedding size: 1536
# doc_id 4290253, embedding size: 1536
# doc_id 606602, embedding size: 1536
# doc_id 1124192350, embedding size: 1536
# doc_id 8293177, embedding size: 1536
# doc_id 265687, embedding size: 1536
# doc_id 205699, embedding size: 1536
# doc_id 4345540, embedding size: 1536
# doc_id 6031740, embedding size: 1536
# doc_id 1121350935, embedding size: 1536
# doc_id 4598721, embedding size: 1536
# doc_id 392994086, embedding size: 1536
# doc_id 5029601, embedding size: 1536
# doc_id 278696, embedding size: 1536
# doc_id 23106, embedding size: 1536
# doc_id 907391, embedding size: 1536
# doc_id 4305136, embedding size: 1536
# doc_id 6277279, embedding size: 1536
# doc_id 743609, embedding size: 1536
# doc_id 5538246, embedding size: 1536
# doc_id 14690674, embedding size: 1536
# doc_id 5465942, embedding size: 1536
# doc_id 115009, embedding size: 1536
# doc_id 8228843, embedding size: 1536
# doc_id 5095610, embedding size: 1536
# doc_id 5638762, embedding size: 1536
# doc_id 1121794390, embedding size: 1536
# doc_id 6624108, embedding size: 1536
# doc_id 5493892, embedding size: 1536
# doc_id 5527245, embedding size: 1536
# doc_id 328050118, embedding size: 1536
# doc_id 6169538, embedding size: 1536
# doc_id 3234552, embedding size: 1536
# doc_id 1122398638, embedding size: 1536
# doc_id 1122243701, embedding size: 1536
# doc_id 4923745, embedding size: 1536
# doc_id 22682, embedding size: 1536
# doc_id 1121416348, embedding size: 1536
# doc_id 395687080, embedding size: 1536
# doc_id 7864545, embedding size: 1536
# doc_id 16969958, embedding size: 1536
# doc_id 5086769, embedding size: 1536
# doc_id 5018147, embedding size: 1536
# doc_id 1123898109, embedding size: 1536
# doc_id 6730012, embedding size: 1536
# doc_id 599738, embedding size: 1536
# doc_id 1122476197, embedding size: 1536
# doc_id 400195116, embedding size: 1536
# doc_id 1123357736, embedding size: 1536
# doc_id 782657, embedding size: 1536
# doc_id 5139215, embedding size: 1536
# doc_id 6895029, embedding size: 1536
# doc_id 1121312319, embedding size: 1536
# doc_id 1123692407, embedding size: 1536
# doc_id 1123877008, embedding size: 1536
# doc_id 7708090, embedding size: 1536
# doc_id 6138814, embedding size: 1536
# doc_id 1121412646, embedding size: 1536
# doc_id 395315429, embedding size: 1536
# doc_id 338338937, embedding size: 1536
# doc_id 639257194, embedding size: 1536
# doc_id 393280438, embedding size: 1536
# doc_id 6285954, embedding size: 1536
# doc_id 1121379114, embedding size: 1536
# doc_id 1123455530, embedding size: 1536
# doc_id 870614, embedding size: 1536
# doc_id 152971, embedding size: 1536
# doc_id 406724775, embedding size: 1536
# doc_id 399977016, embedding size: 1536
# doc_id 1123631808, embedding size: 1536
# doc_id 786077, embedding size: 1536
# doc_id 394994182, embedding size: 1536
# doc_id 16618576, embedding size: 1536
# doc_id 1122257147, embedding size: 1536
# doc_id 85081, embedding size: 1536
# doc_id 3126908, embedding size: 1536
# doc_id 943741, embedding size: 1536
# doc_id 301745, embedding size: 1536
# doc_id 884670, embedding size: 1536
# doc_id 2893119, embedding size: 1536
# doc_id 14684849, embedding size: 1536
# doc_id 268212, embedding size: 1536
# ...
# doc_id 395282146, embedding size: 1536
# doc_id 400174430, embedding size: 1536
# doc_id 311630377, embedding size: 1536
# doc_id 1124026027, embedding size: 1536
# doc_id 1121281959, embedding size: 1536
# doc_id 393387899, embedding size: 1536
# doc_id 6529, embedding size: 1536
# doc_id 1121801691, embedding size: 1536
# doc_id 223885, embedding size: 1536
# doc_id 927178374, embedding size: 1536
# doc_id 557903, embedding size: 1536
# doc_id 5671032, embedding size: 1536
# doc_id 585717, embedding size: 1536
# doc_id 5153352, embedding size: 1536
# doc_id 3404814, embedding size: 1536
# doc_id 5738634, embedding size: 1536
# doc_id 394274, embedding size: 1536
# doc_id 4235686, embedding size: 1536
# doc_id 667131, embedding size: 1536
# doc_id 340559, embedding size: 1536
# doc_id 3582489, embedding size: 1536
# doc_id 959962, embedding size: 1536
# doc_id 135213, embedding size: 1536
# doc_id 104200, embedding size: 1536
# doc_id 40846, embedding size: 1536
# doc_id 64449, embedding size: 1536
# doc_id 4086092, embedding size: 1536
# doc_id 16969732, embedding size: 1536
# doc_id 33405, embedding size: 1536
# doc_id 5517473, embedding size: 1536
# doc_id 185012, embedding size: 1536
# doc_id 588691, embedding size: 1536
# doc_id 6178025, embedding size: 1536
# doc_id 192629, embedding size: 1536
# doc_id 5319977, embedding size: 1536
# doc_id 916941, embedding size: 1536
# doc_id 639312237, embedding size: 1536
# doc_id 5504940, embedding size: 1536
# doc_id 2555910, embedding size: 1536
# doc_id 550875, embedding size: 1536
# doc_id 5043655, embedding size: 1536
# doc_id 597676, embedding size: 1536
# doc_id 282765, embedding size: 1536
# doc_id 5879083, embedding size: 1536
# doc_id 4121734, embedding size: 1536
# doc_id 584872, embedding size: 1536
# doc_id 518445, embedding size: 1536
# doc_id 543693, embedding size: 1536
# doc_id 6928547, embedding size: 1536
# doc_id 585065, embedding size: 1536
# doc_id 3882653, embedding size: 1536
# doc_id 668379, embedding size: 1536
# doc_id 2891561, embedding size: 1536
# doc_id 5003455, embedding size: 1536
# doc_id 221847, embedding size: 1536
# doc_id 175494, embedding size: 1536
# doc_id 105186, embedding size: 1536
# doc_id 14514578, embedding size: 1536
# doc_id 41391, embedding size: 1536
# doc_id 2855685, embedding size: 1536
# doc_id 279310, embedding size: 1536
# doc_id 301512, embedding size: 1536
# doc_id 781744, embedding size: 1536
# doc_id 18211456, embedding size: 1536
# doc_id 2810867, embedding size: 1536
# doc_id 295040, embedding size: 1536
# doc_id 14529710, embedding size: 1536
# doc_id 573900, embedding size: 1536
# doc_id 552780, embedding size: 1536
# doc_id 6405689, embedding size: 1536
# doc_id 7899350, embedding size: 1536
# doc_id 483597, embedding size: 1536
# doc_id 268922, embedding size: 1536
# doc_id 931897, embedding size: 1536
# doc_id 300612, embedding size: 1536
# doc_id 679940, embedding size: 1536
# doc_id 392872, embedding size: 1536
# doc_id 2083819, embedding size: 1536
# doc_id 8709102, embedding size: 1536
# doc_id 7441007, embedding size: 1536
# doc_id 1122362754, embedding size: 1536
# doc_id 826399, embedding size: 1536
# doc_id 3763164, embedding size: 1536
# doc_id 4354811, embedding size: 1536
# doc_id 4109751, embedding size: 1536
# doc_id 132024, embedding size: 1536
# doc_id 3473743, embedding size: 1536
# doc_id 640135474, embedding size: 1536
# doc_id 55227, embedding size: 1536
# doc_id 4353363, embedding size: 1536
# doc_id 368899, embedding size: 1536
# doc_id 593962, embedding size: 1536
# doc_id 76161, embedding size: 1536
# doc_id 681804, embedding size: 1536
# doc_id 4774635, embedding size: 1536
# doc_id 719272, embedding size: 1536
# doc_id 853994, embedding size: 1536
# doc_id 5547613, embedding size: 1536
# doc_id 3943633, embedding size: 1536
# doc_id 5349360, embedding size: 1536
# doc_id 3758766, embedding size: 1536
# doc_id 6165595, embedding size: 1536
# doc_id 72044, embedding size: 1536
# doc_id 5526757, embedding size: 1536
# doc_id 694544, embedding size: 1536
# doc_id 5693334, embedding size: 1536
# doc_id 391816549, embedding size: 1536
# doc_id 310736, embedding size: 1536
# doc_id 4330359, embedding size: 1536
# doc_id 8352391, embedding size: 1536
# doc_id 7619539, embedding size: 1536
# doc_id 883839, embedding size: 1536
# doc_id 554223, embedding size: 1536
# doc_id 722738, embedding size: 1536
# doc_id 2363392, embedding size: 1536
# doc_id 6986633, embedding size: 1536
# doc_id 1271187, embedding size: 1536
# doc_id 1122297039, embedding size: 1536
# doc_id 830836, embedding size: 1536
# doc_id 6062749, embedding size: 1536
# doc_id 2222258, embedding size: 1536
# doc_id 4369155, embedding size: 1536
# doc_id 7192895, embedding size: 1536
# doc_id 246233, embedding size: 1536
# doc_id 4884397, embedding size: 1536
# doc_id 16876, embedding size: 1536
# doc_id 8331329, embedding size: 1536
# doc_id 14415111, embedding size: 1536
# doc_id 6303784, embedding size: 1536
# doc_id 6309414, embedding size: 1536
# doc_id 465240, embedding size: 1536
# doc_id 1555895, embedding size: 1536
# doc_id 4338143, embedding size: 1536
# doc_id 4497628, embedding size: 1536
# doc_id 279605, embedding size: 1536
# doc_id 3874020, embedding size: 1536
# doc_id 8333586, embedding size: 1536
# doc_id 79030, embedding size: 1536
# doc_id 14502785, embedding size: 1536
# doc_id 726336, embedding size: 1536
# doc_id 4108382, embedding size: 1536
# doc_id 22153, embedding size: 1536
# doc_id 715601, embedding size: 1536
# doc_id 866648, embedding size: 1536
# doc_id 1123873761, embedding size: 1536
# doc_id 5021031, embedding size: 1536
# doc_id 293718, embedding size: 1536
# doc_id 640131246, embedding size: 1536
# doc_id 1123879380, embedding size: 1536
# doc_id 4019343, embedding size: 1536
# doc_id 15638119, embedding size: 1536
# doc_id 530854, embedding size: 1536
# doc_id 1121286544, embedding size: 1536
# doc_id 5669984, embedding size: 1536
# doc_id 893665, embedding size: 1536
# doc_id 34472, embedding size: 1536
# doc_id 5519541, embedding size: 1536
# doc_id 314978, embedding size: 1536
# doc_id 16944406, embedding size: 1536
# doc_id 3759725, embedding size: 1536
# doc_id 1294664, embedding size: 1536
# doc_id 16866763, embedding size: 1536
# doc_id 1121340403, embedding size: 1536
# doc_id 223343, embedding size: 1536
# doc_id 791111, embedding size: 1536
# doc_id 2217932, embedding size: 1536
# doc_id 6527322, embedding size: 1536
# doc_id 4258709, embedding size: 1536
# doc_id 4111355, embedding size: 1536
# doc_id 5385866, embedding size: 1536
# doc_id 110508, embedding size: 1536
# doc_id 1145828, embedding size: 1536
# doc_id 45030, embedding size: 1536
# doc_id 2837091, embedding size: 1536
# doc_id 939993, embedding size: 1536
# doc_id 1441442, embedding size: 1536
# doc_id 4416011, embedding size: 1536
# doc_id 350821, embedding size: 1536
# doc_id 4555138, embedding size: 1536
# doc_id 6274966, embedding size: 1536
# doc_id 5101564, embedding size: 1536
# doc_id 1123814724, embedding size: 1536
# doc_id 1098235, embedding size: 1536
# doc_id 1123670964, embedding size: 1536
# doc_id 263265, embedding size: 1536
# doc_id 78667, embedding size: 1536
# doc_id 1123840958, embedding size: 1536
# doc_id 5334451, embedding size: 1536
# doc_id 198598, embedding size: 1536
# doc_id 1123766626, embedding size: 1536
# doc_id 4141346, embedding size: 1536
# doc_id 4365634, embedding size: 1536
# doc_id 6123021, embedding size: 1536
# doc_id 4365915, embedding size: 1536
# doc_id 406752389, embedding size: 1536
# doc_id 4856876, embedding size: 1536
# doc_id 6262986, embedding size: 1536
# doc_id 1123818227, embedding size: 1536
# doc_id 1122937664, embedding size: 1536
# doc_id 2094653, embedding size: 1536
# doc_id 31353, embedding size: 1536
# doc_id 192658, embedding size: 1536
# doc_id 8636470, embedding size: 1536
# doc_id 6039423, embedding size: 1536
# doc_id 6266444, embedding size: 1536
# doc_id 16885212, embedding size: 1536
# doc_id 1124060114, embedding size: 1536
# doc_id 605186, embedding size: 1536
# doc_id 175241, embedding size: 1536
# doc_id 1635435331, embedding size: 1536
# doc_id 567241, embedding size: 1536
# doc_id 1121239754, embedding size: 1536
# doc_id 402857238, embedding size: 1536
# doc_id 120911, embedding size: 1536
# doc_id 8789722, embedding size: 1536
# doc_id 40858, embedding size: 1536
# doc_id 5160120, embedding size: 1536
# doc_id 5595011, embedding size: 1536
# doc_id 269902, embedding size: 1536
# doc_id 1123711799, embedding size: 1536
# doc_id 3676813, embedding size: 1536
# doc_id 550622, embedding size: 1536
# doc_id 5464730, embedding size: 1536
# doc_id 791223, embedding size: 1536
# doc_id 339107, embedding size: 1536
# doc_id 756400, embedding size: 1536
# doc_id 6294836, embedding size: 1536
# doc_id 548693, embedding size: 1536
# doc_id 6254841, embedding size: 1536
# doc_id 159138, embedding size: 1536
# doc_id 5234385, embedding size: 1536
# doc_id 279947, embedding size: 1536
# doc_id 3974725, embedding size: 1536
# doc_id 921109, embedding size: 1536
# doc_id 593844, embedding size: 1536
# doc_id 19928, embedding size: 1536
# doc_id 640741, embedding size: 1536
# doc_id 484653, embedding size: 1536
# doc_id 6165850, embedding size: 1536
# doc_id 4201729, embedding size: 1536
# doc_id 583803, embedding size: 1536
# doc_id 3949649, embedding size: 1536
# doc_id 525370, embedding size: 1536
# doc_id 14695777, embedding size: 1536
# doc_id 550027, embedding size: 1536
# doc_id 6031243, embedding size: 1536
# doc_id 11145, embedding size: 1536
# doc_id 1122836312, embedding size: 1536
# doc_id 6235521, embedding size: 1536
# doc_id 691879, embedding size: 1536
# doc_id 2897993, embedding size: 1536
# doc_id 3654147, embedding size: 1536
# doc_id 55209, embedding size: 1536
# doc_id 6344873, embedding size: 1536
# doc_id 6084080, embedding size: 1536
# doc_id 23197847, embedding size: 1536
# doc_id 6063144, embedding size: 1536
# doc_id 1121238628, embedding size: 1536
# doc_id 711205, embedding size: 1536
# doc_id 2623679, embedding size: 1536
# doc_id 30418, embedding size: 1536
# doc_id 4346682, embedding size: 1536
# doc_id 107504, embedding size: 1536
# doc_id 427630, embedding size: 1536
# doc_id 1148901, embedding size: 1536
# doc_id 2781030, embedding size: 1536
# doc_id 221110, embedding size: 1536
# doc_id 3028850, embedding size: 1536
# doc_id 831001, embedding size: 1536
# doc_id 906477, embedding size: 1536
# doc_id 4802047, embedding size: 1536
# doc_id 1123607134, embedding size: 1536
# doc_id 949877, embedding size: 1536
# doc_id 77176, embedding size: 1536
# doc_id 7454723, embedding size: 1536
# doc_id 562976, embedding size: 1536
# doc_id 402864730, embedding size: 1536
# doc_id 787245, embedding size: 1536
# doc_id 395676339, embedding size: 1536
# doc_id 8000822, embedding size: 1536
# doc_id 162237, embedding size: 1536
# doc_id 4067766, embedding size: 1536
# doc_id 5209726, embedding size: 1536
# doc_id 1122382524, embedding size: 1536
# doc_id 4444862, embedding size: 1536
# doc_id 6064609, embedding size: 1536
# doc_id 2056054, embedding size: 1536
# doc_id 6105885, embedding size: 1536
# doc_id 128833329, embedding size: 1536
# doc_id 6235528, embedding size: 1536
# doc_id 4390260, embedding size: 1536
# doc_id 662879, embedding size: 1536
# doc_id 155717, embedding size: 1536
# doc_id 130194553, embedding size: 1536
# doc_id 2054504, embedding size: 1536
# doc_id 10038, embedding size: 1536
# doc_id 6295681, embedding size: 1536
# doc_id 1123804142, embedding size: 1536
# doc_id 5698282, embedding size: 1536
# doc_id 57994, embedding size: 1536
# doc_id 6257441, embedding size: 1536
# doc_id 16967503, embedding size: 1536
# doc_id 900728, embedding size: 1536
# doc_id 5397189, embedding size: 1536
# doc_id 231442, embedding size: 1536
# doc_id 587235, embedding size: 1536
# doc_id 2062998, embedding size: 1536
# doc_id 876778, embedding size: 1536
# doc_id 406755352, embedding size: 1536
# doc_id 5316014, embedding size: 1536
# doc_id 711919, embedding size: 1536
# doc_id 274122, embedding size: 1536
# doc_id 14591082, embedding size: 1536
# doc_id 688317, embedding size: 1536
# doc_id 6348370, embedding size: 1536
# doc_id 6129528, embedding size: 1536
# doc_id 255762, embedding size: 1536
# doc_id 925269, embedding size: 1536
# doc_id 8101, embedding size: 1536
# doc_id 129435, embedding size: 1536
# doc_id 603559, embedding size: 1536
# doc_id 79179, embedding size: 1536
# doc_id 16866238, embedding size: 1536
# doc_id 4244015, embedding size: 1536
# doc_id 23313328, embedding size: 1536
# doc_id 16996617, embedding size: 1536
# doc_id 4907848, embedding size: 1536
# doc_id 37639, embedding size: 1536
# doc_id 1122838404, embedding size: 1536
# doc_id 393669022, embedding size: 1536
# doc_id 241673, embedding size: 1536
# doc_id 8724234, embedding size: 1536
# doc_id 14979412, embedding size: 1536
# doc_id 787058, embedding size: 1536
# doc_id 29408, embedding size: 1536
# doc_id 1121829436, embedding size: 1536
# doc_id 5026581, embedding size: 1536
# doc_id 602155, embedding size: 1536
# doc_id 226307, embedding size: 1536
# doc_id 6390009, embedding size: 1536
# doc_id 203865, embedding size: 1536
# doc_id 4571534, embedding size: 1536
# doc_id 6243789, embedding size: 1536
# doc_id 2044315, embedding size: 1536
# doc_id 47845, embedding size: 1536
# doc_id 29811, embedding size: 1536
# doc_id 1655195, embedding size: 1536
# doc_id 130499905, embedding size: 1536
# doc_id 129332094, embedding size: 1536
# doc_id 1123723701, embedding size: 1536
# doc_id 204316, embedding size: 1536
# doc_id 1371171, embedding size: 1536
# doc_id 1879770, embedding size: 1536
# doc_id 6268179, embedding size: 1536
# doc_id 2192146, embedding size: 1536
# doc_id 6264263, embedding size: 1536
# doc_id 378716, embedding size: 1536
# doc_id 202530, embedding size: 1536
# doc_id 6335300, embedding size: 1536
# doc_id 5216089, embedding size: 1536
# doc_id 3082750, embedding size: 1536
# doc_id 265977, embedding size: 1536
# doc_id 5243771, embedding size: 1536
# doc_id 16731802, embedding size: 1536
# doc_id 399888779, embedding size: 1536
# doc_id 14590608, embedding size: 1536
# doc_id 1123758769, embedding size: 1536
# doc_id 6172166, embedding size: 1536
# doc_id 4373509, embedding size: 1536
# doc_id 5548084, embedding size: 1536
# doc_id 5366, embedding size: 1536
# doc_id 4465908, embedding size: 1536
# doc_id 6201128, embedding size: 1536
# doc_id 752056, embedding size: 1536
# doc_id 5073932, embedding size: 1536
# doc_id 2134202, embedding size: 1536
# doc_id 879616, embedding size: 1536
# doc_id 5375203, embedding size: 1536
# doc_id 5665483, embedding size: 1536
# doc_id 1604791, embedding size: 1536
# doc_id 6306131, embedding size: 1536
# doc_id 6181334, embedding size: 1536
# doc_id 2350560, embedding size: 1536
# doc_id 1264855, embedding size: 1536
# doc_id 1121035094, embedding size: 1536
# doc_id 1123875989, embedding size: 1536
# doc_id 4418080, embedding size: 1536
# doc_id 14709925, embedding size: 1536
# doc_id 137932456, embedding size: 1536
# doc_id 1123960373, embedding size: 1536
# doc_id 3702761, embedding size: 1536
# doc_id 1121192537, embedding size: 1536
# doc_id 294776828, embedding size: 1536
# doc_id 1032285, embedding size: 1536
# doc_id 6718480, embedding size: 1536
# doc_id 1121322671, embedding size: 1536
# doc_id 394034948, embedding size: 1536
# doc_id 15455559, embedding size: 1536
# doc_id 6391656, embedding size: 1536
# doc_id 1123747459, embedding size: 1536
# doc_id 514113, embedding size: 1536
# doc_id 6183043, embedding size: 1536
# doc_id 16994057, embedding size: 1536
# doc_id 14724818, embedding size: 1536
# doc_id 1123790320, embedding size: 1536
# doc_id 1121204466, embedding size: 1536
# doc_id 1122824077, embedding size: 1536
# doc_id 395828988, embedding size: 1536
# doc_id 14504307, embedding size: 1536
# doc_id 1122417681, embedding size: 1536
# doc_id 1123760158, embedding size: 1536
# doc_id 1122823560, embedding size: 1536
# doc_id 23275738, embedding size: 1536
# doc_id 1122302828, embedding size: 1536
# doc_id 1121032986, embedding size: 1536
# doc_id 401180960, embedding size: 1536
# doc_id 1123711509, embedding size: 1536
# doc_id 129329409, embedding size: 1536
# doc_id 1122383911, embedding size: 1536
# doc_id 395304541, embedding size: 1536
